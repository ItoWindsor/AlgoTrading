# %%
import os 
import sys
import inspect
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
import src.portfolio as portfolio
import src.stock as stock

# %%
AAPL = stock.Stock(ticker = "AAPL")

# %%
AAPL.data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099450
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094261
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087343
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089504
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092099
# ...          ...         ...         ...         ...         ...         ...
# 10755 2023-08-11  177.320007  178.619995  176.550003  177.789993  177.789993
# 10756 2023-08-14  177.970001  179.690002  177.309998  179.460007  179.460007
# 10757 2023-08-15  178.880005  179.479996  177.050003  177.449997  177.449997
# 10758 2023-08-16  177.130005  178.539993  176.500000  176.570007  176.570007
# 10759 2023-08-17  177.139999  177.509995  173.479996  174.000000  174.000000
#
#           Volume
# 0      469033600
# ...

# %%
AAPL.plot_histogram()

# %%
V = portfolio.Portfolio(tickers = ("AAPL","JPM","AMZN","DIS","XOM"))

# %%
V["AMZN"].plot_histogram()

# %%
print(V)
# Out:
# assets : AAPL JPM AMZN DIS XOM

# %%
V.plot_prices(normalized_data = False)

# %%
V.plot_prices(tickers= ("AAPL","JPM","GS"), normalized_data= True)

# %%
start_date = "2010-10-3"
end_date = "2020-4-13"

# %%
V.plot_prices(tickers= ("AAPL","AMZN","GS"), normalized_data= True, start_date = start_date, end_date = end_date)

# %%
V.compute_correlations(tickers = ("AAPL","AMZN","DIS"), start_date = start_date, end_date = end_date)
# Out:
# array([[1.        , 0.93494643, 0.86171984],
#        [0.93494643, 1.        , 0.82134692],
#        [0.86171984, 0.82134692, 1.        ]])

# %%
V.plot_heatmap(tickers = ("AAPL","AMZN","DIS"), start_date = start_date, end_date = end_date)

# %%
start_date2 = "2018-10-10"
end_date2 = "2021-10-10"
V.plot_heatmap(start_date = start_date2, end_date = end_date2)

# %%
V.add_indicators(indicator= 'log return 1D', start_date = start_date, end_date = end_date)
# Out:
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['log return 1D'][(self.data["Date"] >= start_date) & (self.data["Date"] <= end_date)] = temp
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['log return 1D'][(self.data["Date"] >= start_date) & (self.data["Date"] <= end_date)] = temp
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
V['AMZN'].plot_histogram(column_name = 'log return 1D', start_date = start_date, end_date = end_date)

# %%
V['DIS'].plot_histogram(column_name = 'log return 1D')

# %%
V.plot_histogram(column_name= 'log return 1D', start_date = start_date, end_date =end_date)

# %%
new_quantities = {"AAPL" : 10, 'JPM' : -3, 'AMZN' : -2 , 'DIS' : 1}
V.update_quantities(new_quantities= new_quantities)

# %%
V.plot_value_portfolio(start_date = start_date, end_date = end_date)

# %%
portefeuille = portfolio.Portfolio(tickers = ('AAPL','GS','JPM','AMZN'))

# %%
portefeuille.assets['AAPL'].data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099450
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094261
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087343
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089504
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092099
# ...          ...         ...         ...         ...         ...         ...
# 10755 2023-08-11  177.320007  178.619995  176.550003  177.789993  177.789993
# 10756 2023-08-14  177.970001  179.690002  177.309998  179.460007  179.460007
# 10757 2023-08-15  178.880005  179.479996  177.050003  177.449997  177.449997
# 10758 2023-08-16  177.130005  178.539993  176.500000  176.570007  176.570007
# 10759 2023-08-17  177.139999  177.509995  173.479996  174.000000  174.000000
#
#           Volume
# 0      469033600
# ...

# %%
portefeuille['AAPL']['Adj Close']
# Out:
# 0          0.099450
# 1          0.094261
# 2          0.087343
# 3          0.089504
# 4          0.092099
#             ...
# 10755    177.789993
# 10756    179.460007
# 10757    177.449997
# 10758    176.570007
# 10759    174.000000
# Name: Adj Close, Length: 10760, dtype: float64

# %%
portefeuille.add_indicators(indicator= 'log return 1D')
# Out:
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['log return 1D'][(self.data["Date"] >= start_date) & (self.data["Date"] <= end_date)] = temp
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['log return 1D'][(self.data["Date"] >= start_date) & (self.data["Date"] <= end_date)] = temp
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
portefeuille['AAPL'].plot_histogram(column_name= 'log return 1D')
