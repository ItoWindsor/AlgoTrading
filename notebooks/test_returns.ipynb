# %%
import pandas as pd

# %%
import src.marketdata as marketdata
import src.stock as stock

# %%
market = marketdata.Marketdata(tickers = ("AAPL","JPM","AMZN","DIS","XOM"))

# %%
start_date = "2010-10-3"
end_date = "2020-4-13"

# %%
market.add_indicators(indicator= 'log return 1d', start_date = start_date, end_date = end_date)
# Out:
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data[indicator.value][(self.data["Date"] >= start_date) & (self.data["Date"] <= end_date)] = temp
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data[indicator.value][(self.data["Date"] >= start_date) & (self.data["Date"] <= end_date)] = temp
# C:\Users\Imad\Desktop\pour Github\AlgoTrading\src\stock.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
market.plot_heatmap(start_date = start_date, end_date = end_date)

# %%
market['AAPL'].data['log return 1d'].hist()
# Out:
# <AxesSubplot:>
